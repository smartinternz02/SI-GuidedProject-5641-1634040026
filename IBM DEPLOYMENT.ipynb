# %% [markdown]
# # Data Preprocessing
#
# Data Pre-processing includes the following main tasks
#
# 1.Import the Libraries.
#
# 2.Importing the dataset.
#
# 3.Checking for Null Values.
#
# 4.Data Visualization.
#
# 5.Label Encoding.
#
# 6.OneHot Encoding.
#
# 7.Splitting Data into Train and Test.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

if os.environ.get('RUNTIME_ENV_LOCATION_TYPE') == 'external':
    endpoint_351b9037ca28460daeb4179232e3f6b8 = 'https://s3.us.cloud-object-storage.appdomain.cloud'
else:
    endpoint_351b9037ca28460daeb4179232e3f6b8 = 'https://s3.private.us.cloud-object-storage.appdomain.cloud'

client_351b9037ca28460daeb4179232e3f6b8 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='8XiXmiwA17ZNlgDl2MpY4KZTY-NRHsm-Z4V5ZFzocmgo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url=endpoint_351b9037ca28460daeb4179232e3f6b8)

body = client_351b9037ca28460daeb4179232e3f6b8.get_object(Bucket='cerealsanalysisbasedonratingsusin-donotdelete-pr-zraijp13cmiqu6',Key='cereal.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

data = pd.read_csv(body)
data.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
data.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# head() method is used to return top n (5 by default) rows of a DataFrame or series.

# %%
data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %% [markdown]
# describe() method computes a summary of statistics like count, mean, standard deviation, min, max and quartile values.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %% [markdown]
# info() gives information about the data

# %%
data.drop(["name"],axis=1,inplace=True)

# %%
data
# Out:
#    mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 0    N    C        70        4    1     130   10.0    5.0       6     280
# 1    Q    C       120        3    5      15    2.0    8.0       8     135
# 2    K    C        70        4    1     260    9.0    7.0       5     320
# 3    K    C        50        4    0     140   14.0    8.0       0     330
# 4    R    C       110        2    2     200    1.0   14.0       8      -1
# ..  ..  ...       ...      ...  ...     ...    ...    ...     ...     ...
# 72   G    C       110        2    1     250    0.0   21.0       3      60
# 73   G    C       110        1    1     140    0.0   13.0      12      25
# 74   R    C       100        3    1     230    3.0   17.0       3     115
# 75   G    C       100        3    1     200    3.0   17.0       3     110
# 76   G    C       110        2    1     200    1.0   16.0       8      60
#
#     vitamins  shelf  weight  cups     rating
# ...

# %% [markdown]
# # Imputing data using Imputation method in sklearn

# %%
data.isnull().any()
# Out:
# mfr         False
# type        False
# calories    False
# protein     False
# fat         False
# sodium      False
# fiber       False
# carbo       False
# sugars      False
# potass      False
# vitamins    False
# shelf       False
# weight      False
# cups        False
# rating      False
# dtype: bool

# %%
data.head(69)
# Out:
#    mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 0    N    C        70        4    1     130   10.0    5.0       6     280
# 1    Q    C       120        3    5      15    2.0    8.0       8     135
# 2    K    C        70        4    1     260    9.0    7.0       5     320
# 3    K    C        50        4    0     140   14.0    8.0       0     330
# 4    R    C       110        2    2     200    1.0   14.0       8      -1
# ..  ..  ...       ...      ...  ...     ...    ...    ...     ...     ...
# 64   N    C        90        3    0       0    4.0   19.0       0     140
# 65   N    C        90        3    0       0    3.0   20.0       0     120
# 66   K    C       110        2    1      70    1.0    9.0      15      40
# 67   K    C       110        6    0     230    1.0   16.0       3      55
# 68   N    C        90        2    0      15    3.0   15.0       5      90
#
#     vitamins  shelf  weight  cups     rating
# ...

# %% [markdown]
# There are no Null values present in the dataset.

# %% [markdown]
# # Heatmap:It is way of representing the data in 2-D form.It gives coloured visual summary of the data

# %%
plt.figure(figsize = (14,8))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the heatmap, we see that there are no missing values in the dataset

# %% [markdown]
# # Before diving into the code, let's look at some of the basic properties we will be using when plotting.
#
# xlabel: Set the label for the x-axis.
#
# ylabel: Set the label for the y-axis.

# %% [markdown]
# # 1.data.corr() gives the correlation between the columns

# %%
data.corr()
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.019066  0.498610  0.300649 -0.293413  0.250681
# protein   0.019066  1.000000  0.208431 -0.054674  0.500330 -0.130864
# fat       0.498610  0.208431  1.000000 -0.005407  0.016719 -0.318043
# sodium    0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.355983
# fiber    -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.356083
# carbo     0.250681 -0.130864 -0.318043  0.355983 -0.356083  1.000000
# sugars    0.562340 -0.329142  0.270819  0.101451 -0.141205 -0.331665
# potass   -0.066609  0.549407  0.193279 -0.032603  0.903374 -0.349685
# vitamins  0.265356  0.007335 -0.031156  0.361477 -0.032243  0.258148
# shelf     0.097234  0.133865  0.263691 -0.069719  0.297539 -0.101790
# weight    0.696091  0.216158  0.214625  0.308576  0.247226  0.135136
# cups      0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.363932
# rating   -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.052055
#
# ...

# %% [markdown]
# # 2.Box plot

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data = data, x = "mfr", y = "rating")
# Out:
# <AxesSubplot:xlabel='mfr', ylabel='rating'>

# %% [markdown]
# # 3.Pairplot

# %%
#sns.pairplot(data = data,markers = ["^","v"] , palette= "red")

# %% [markdown]
#  # Label Encoding refers to converting the labels into numeric form so as to convert it into the machine-readable form.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['mfr'] = le.fit_transform(data['mfr'])
data['type'] = le.fit_transform(data['type'])

# %% [markdown]
# Data after label encoding

# %%
data
# Out:
#     mfr  type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 0     3     0        70        4    1     130   10.0    5.0       6     280
# 1     5     0       120        3    5      15    2.0    8.0       8     135
# 2     2     0        70        4    1     260    9.0    7.0       5     320
# 3     2     0        50        4    0     140   14.0    8.0       0     330
# 4     6     0       110        2    2     200    1.0   14.0       8      -1
# ..  ...   ...       ...      ...  ...     ...    ...    ...     ...     ...
# 72    1     0       110        2    1     250    0.0   21.0       3      60
# 73    1     0       110        1    1     140    0.0   13.0      12      25
# 74    6     0       100        3    1     230    3.0   17.0       3     115
# 75    1     0       100        3    1     200    3.0   17.0       3     110
# 76    1     0       110        2    1     200    1.0   16.0       8      60
#
#     vitamins  shelf  weight  cups     rating
# ...

# %% [markdown]
# All the data is converted into numerical values.

# %% [markdown]
# # Spliting our dataset into independent and dependent variables.

# %%
x = data.iloc[:,0:14].values
y = data.iloc[:,14:15].values

# %%
x
# Out:
# array([[  3.  ,   0.  ,  70.  , ...,   3.  ,   1.  ,   0.33],
#        [  5.  ,   0.  , 120.  , ...,   3.  ,   1.  ,   1.  ],
#        [  2.  ,   0.  ,  70.  , ...,   3.  ,   1.  ,   0.33],
#        ...,
#        [  6.  ,   0.  , 100.  , ...,   1.  ,   1.  ,   0.67],
#        [  1.  ,   0.  , 100.  , ...,   1.  ,   1.  ,   1.  ],
#        [  1.  ,   0.  , 110.  , ...,   1.  ,   1.  ,   0.75]])

# %%
y
# Out:
# array([[68.402973],
#        [33.983679],
#        [59.425505],
#        [93.704912],
#        [34.384843],
#        [29.509541],
#        [33.174094],
#        [37.038562],
#        [49.120253],
#        [53.313813],
#        [18.042851],
#        [50.764999],
#        [19.823573],
#        [40.400208],
#        [22.736446],
#        [41.445019],
#        [45.863324],
#        [35.782791],
#        [22.396513],
#        [40.448772],
#        [64.533816],
#        [46.895644],
#        [36.176196],
#        [44.330856],
#        [32.207582],
#        [31.435973],
#        [58.345141],
#        [40.917047],
#        [41.015492],
#        [28.025765],
#        [35.252444],
#        [23.804043],
#        [52.076897],
#        [53.371007],
#        [45.811716],
#        [21.871292],
#        [31.072217],
#        [28.742414],
#        [36.523683],
#        [36.471512],
#        [39.241114],
#        [45.328074],
#        [26.734515],
#        [54.850917],
#        [37.136863],
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder()
a = one.fit_transform(x[:,0:1]).toarray()
x = np.delete(x,[0],axis=1)
x = np.concatenate((a,x),axis=1)

# %% [markdown]
# # Now split our dataset into a train set and test using train_test_split class from scikit learn library.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2,random_state = 0)
#random_state acts as the seed for the random number generator during the split

# %% [markdown]
# # We are using the algorithm from Scikit learn library to build the model as shown below,

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_train[0]
# Out:
# array([  0.  ,   1.  ,   0.  ,   0.  ,   0.  ,   0.  ,   0.  ,   0.  ,
#        100.  ,   2.  ,   1.  , 140.  ,   2.  ,  11.  ,  10.  , 120.  ,
#         25.  ,   3.  ,   1.  ,   0.75])

# %%
lr_pred = lr.predict(x_test)
lr_pred
# Out:
# array([[29.92428517],
#        [49.78744507],
#        [39.70339959],
#        [60.75611161],
#        [45.81171618],
#        [58.3451415 ],
#        [59.36399361],
#        [53.37100755],
#        [34.13976435],
#        [38.8397453 ],
#        [40.91704712],
#        [55.33314186],
#        [93.70491267],
#        [26.73451534],
#        [54.85091689],
#        [37.03856175]])

# %% [markdown]
# Once the model is trained, it’s ready to make predictions. We can use the predict method on the model and pass x_test as a parameter to get the output as y_pred.

# %%
y_p = lr.predict([[0,0,0,0,1,0,0,0,70,4,1,130,10,5,6,280,25,3,1,0.33]])
y_p
# Out:
# array([[68.40297324]])

# %% [markdown]
# # For testing the model we use the below method,

# %%
from sklearn.metrics import r2_score
r2_score(y_test,lr_pred)
# Out:
# 0.9999999999999992

# %% [markdown]
# # After building the model we have to save the model.
#
# Pickle in Python is primarily used in serializing and deserializing a Python object structure.

# %%
import pickle
pickle.dump(lr,open('cerealanalysis.pkl','wb'))
model=pickle.load(open('cerealanalysis.pkl','rb'))

# %%
# !pip install ibm_watson_machine_learning

# %%
from ibm_watson_machine_learning import APIClient
import json
import numpy as np

# %%
from ibm_watson_machine_learning import APIClient
wml_credentials = {
    "url": "https://us-south.ml.cloud.ibm.com",
    "apikey":"kts70omrII5P-4S9XCV-xWlxqmQouW65uEqcB__CiWIA"
}
client = APIClient(wml_credentials)

# %%
def guid_from_space_name(client, space_name):
    space = client.spaces.get_details()
    #print(space)
    return(next(item for item in space['resources'] if item['entity']["name"] == space_name)['metadata']['id'])

# %%
space_uid = guid_from_space_name(client, 'mini_project')
print("Space UID - " + space_uid)
# Out:
# Space UID - cb4171e8-1a79-4dc2-88ba-b25ad66aa3f3

# %%
client.set.default_space(space_uid)
# Out:
# 'SUCCESS'

# %%
software_spec_uid = client.software_specifications.get_uid_by_name("default_py3.7")
software_spec_uid
# Out:
# 'e4429883-c883-42b6-87a8-f419d64088cd'

# %% [markdown]
# # Save and Deploy Model

# %%
import sklearn
sklearn.__version__
# Out:
# '0.23.2'

# %%
MODEL_NAME = 'Cereal_Analysis'
DEPLOYMENT_NAME = 'Cereal_Analysis_deploy'
CEREAL_MODEL = lr

# %%
# Set Python Version
software_spec_uid = client.software_specifications.get_id_by_name('default_py3.8')

# Setup model meta
model_props = {
    client.repository.ModelMetaNames.NAME: "Cereal_Analysis", 
    client.repository.ModelMetaNames.TYPE: 'scikit-learn_0.23', 
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid 
}

# %%
#Save model
model_details = client.repository.store_model(
    model= CEREAL_MODEL, 
    meta_props= model_props, 
    training_data = x_train, 
    training_target = y_train
)

# %%
model_uid = client.repository.get_model_uid(model_details); model_uid
# Out:
# 'e2e219e7-1467-48df-a4ec-d71bfc2efdae'

# %%
x_train[0]
# Out:
# array([  0.  ,   1.  ,   0.  ,   0.  ,   0.  ,   0.  ,   0.  ,   0.  ,
#        100.  ,   2.  ,   1.  , 140.  ,   2.  ,  11.  ,  10.  , 120.  ,
#         25.  ,   3.  ,   1.  ,   0.75])

# %%
lr.predict([[  0.  ,   1.  ,   0.  ,   0.  ,   0.  ,   0.  ,   0.  ,   0.  ,
       100.  ,   2.  ,   1.  , 140.  ,   2.  ,  11.  ,  10.  , 120.  ,
        25.  ,   3.  ,   1.  ,   0.75]])
# Out:
# array([[36.1761961]])
